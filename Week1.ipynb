# %%
#Imports!
import pandas as pd
import glob

# %%
# Creating dataframe with Listing Files
listing_files = glob.glob("Listing/CRMLSListing*.csv")
listed_df = pd.concat([pd.read_csv(f)for f in listing_files], ignore_index=True)

# %%
# Creating dataframe with Sold Files
sold_files = glob.glob("Sold/CRMLSSold*.csv")
sold_df = pd.concat([pd.read_csv(s)for s in sold_files], ignore_index=True)
# Out:
# /var/folders/l4/hlg0lrhx2_79czgk4q732ylw0000gq/T/ipykernel_2798/780542360.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold_df = pd.concat([pd.read_csv(s)for s in sold_files], ignore_index=True)
# /var/folders/l4/hlg0lrhx2_79czgk4q732ylw0000gq/T/ipykernel_2798/780542360.py:2: DtypeWarning: Columns (4,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold_df = pd.concat([pd.read_csv(s)for s in sold_files], ignore_index=True)
# /var/folders/l4/hlg0lrhx2_79czgk4q732ylw0000gq/T/ipykernel_2798/780542360.py:2: DtypeWarning: Columns (2,36,39,56,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold_df = pd.concat([pd.read_csv(s)for s in sold_files], ignore_index=True)

# %%
# Listing Df Shape
listed_df.shape
# Out:
# (814852, 84)

# %%
# Sold Df Shape
sold_df.shape
# Out:
# (568161, 84)
